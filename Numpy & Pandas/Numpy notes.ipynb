# %%
import numpy as np

# %%
a = np.array(["a","b","c"])
a
# Out:
# array(['a', 'b', 'c'], dtype='<U1')

# %%
a[[2,0]]
# Out:
# array(['c', 'a'], dtype='<U1')

# %%
b = np.array([[3,2,1],[7,6,5]])
b
# Out:
# array([[3, 2, 1],
#        [7, 6, 5]])

# %%
b[[1]]
# Out:
# array([[7, 6, 5]])

# %%
b[:,1]
# Out:
# array([2, 6])

# %%
b.shape
# Out:
# (2, 3)

# %%
for x in b.flat : print(x)
# Out:
# 3
# 2
# 1
# 7
# 6
# 5

# %%
b.flat[b.argmax()]
# Out:
# 7

# %%
b.flat[b.argmin()]
# Out:
# 1

# %%
f = lambda x,y :x*y

# %%
f(4,3)
# Out:
# 12
